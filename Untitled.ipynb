# %%
import pandas
sample = pandas.DataFrame.from_csv("sample.csv")
sample.replace(",","")
#sample.applymap(float)
# Out:
#     n      nPx    nDx      nMx    a      nqx     npx       lx     ndx     nLx  \
# x
# 0   1   369300   2022  0.00548  0.1  0.00545  0.9946  100,000     545   99510
# 1   4  1462700    467  0.00032  0.4  0.00128  0.9987   99,455     127  397516
# 5   5  1755600    306  0.00017  0.5  0.00087  0.9991   99,328      87  496425
# 10  5  1974200    394  0.00020  0.5  0.00100  0.9990   99,242      99  495961
# 15  5  1997800   1315  0.00066  0.5  0.00329  0.9967   99,143     326  494899
# 20  5  2041900   2377  0.00116  0.5  0.00580  0.9942   98,817     574  492651
# 25  5  2155700   2824  0.00131  0.5  0.00653  0.9935   98,243     641  489614
# 30  5  2193000   3659  0.00167  0.5  0.00831  0.9917   97,602     811  485983
# 35  5  2150700   4764  0.00222  0.5  0.01101  0.9890   96,791   1,066  481291
# 40  5  2114300   6906  0.00327  0.5  0.01620  0.9838   95,725   1,551  474749
# 45  5  2167100   9944  0.00459  0.5  0.02268  0.9773   94,174   2,136  465532
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-682ea39ff289> in <module>()
# ----> 1 sample.applymap(float)
#
# NameError: name 'sample' is not defined
